# %% [markdown]
# <a href="https://colab.research.google.com/github/ra2git/New_Donor_Email_Prediction/blob/master/Master_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # **Train ANN Model**
#
# This code will train the **New_Donor_ANN_model**
#
# ## Files required for training
#   * emails.csv
#   * interactions.csv
#   * persons.csv
#   * LDA_eachTopic_MatchRate.csv
#   * base_features_ANN.pkl - This will be created within the program
#
#
# ## Files saved after the compilation
#   * base_features_ANN.pkl
#   * New_Donor_ANN_Model.h5
#   * New_Donor_ANN_model_history.sav
#
#
# ## Output
#   * Confusion matrix compating test and train data

# %%
# Run "New_Donor_ANN_model.ipynb"
# !cp "/content/drive/Shared drives/RA2 TechCareers Model Data/New_Donor_Prediction/New_Donor_ANN_model.ipynb" "New_Donor_ANN_model.ipynb"
# %run 'New_Donor_ANN_model.ipynb'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (609, 11)
# (1044769, 8)
# (21066, 14)
# (207, 1)
# (1044769, 4)
# Persons dataset:  (17736, 14)
# Unique genders in dataset:  ['MALE' 'FEMALE' 'OTHERS']
# Unique is_volunteer in dataset:  [True False]
# Unique Cities in dataset:  ['EDMONTON' 'OTHER' 'CALGARY']
# Persons dataset after creating dummy variables:  (17736, 19)
# Persons dataset after dropping unused columns:  (17736, 12)
# Using TensorFlow backend.
# Train on 405000 samples, validate on 45000 samples
# Epoch 1/100
#  - 158s - loss: 0.5007 - accuracy: 0.7591 - val_loss: 0.4947 - val_accuracy: 0.7621
# Epoch 2/100
#  - 156s - loss: 0.4932 - accuracy: 0.7625 - val_loss: 0.4925 - val_accuracy: 0.7639
# Epoch 3/100
#  - 154s - loss: 0.4918 - accuracy: 0.7635 - val_loss: 0.4922 - val_accuracy: 0.7630
# Epoch 4/100
# ...

# %% [markdown]
# # **Train ML Model**
#
# This code will train the **New_Donor_RF_ML_model**
#
# ## Files required for training
#   * emails.csv
#   * interactions.csv
#   * persons.csv
#   * LDA_eachTopic_MatchRate.csv
#   * base_features_ML.pkl - This will be created within the program
#
#
# ## Files saved after the compilation
#   * base_features_ML.pkl
#   * Random_Forest_model_KK.sav
#
#
# ## Output
#   * Confusion matrix compating test and train data

# %%
# Run "New_Donor_RF_ML_model.ipynb"
# !cp "/content/drive/Shared drives/RA2 TechCareers Model Data/New_Donor_Prediction/New_Donor_RF_ML_model.ipynb" "New_Donor_RF_ML_model.ipynb"
# %run 'New_Donor_RF_ML_model.ipynb'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (21064, 14)
# (1005534, 17)
# (1005534, 17)
# (207, 10)
# (1005534, 22)
# (540000, 48)
# (540000,)
# (60000, 48)
# (60000,)
# Accuracy: 75.0 %
# [[22100  7972]
#  [ 6993 22935]]
# Normalized confusion matrix
# [[0.73 0.27]
#  [0.23 0.77]]
#
# Accuracy: 75.0 %

# %% [markdown]
# # **Calculate Content Topic Modeling score**
#
# This code will run LDA topic modeling on Email content and calculate their topic modeling scores.
#
# ## Files required for training
#   * emails.csv
#
#
# ## Files saved after the compilation
#   * LDA_eachTopic_MatchRate.csv
#
#
# ## Output
#   * None

# %%
# Run "Donor-Likelihood-NN_withAllLDACode.ipynb"
# !cp "/content/drive/Shared drives/RA2 TechCareers Model Data/New_Donor_Prediction/Donor-Likelihood-NN_withAllLDACode.ipynb" "Donor-Likelihood-NN_withAllLDACode.ipynb"
# %run 'Donor-Likelihood-NN_withAllLDACode.ipynb'

# %% [markdown]
# # **Calculate Content Topic Modeling score of new Email**
#
# This code will run LDA topic modeling on Email content of any given new email, which will be required for calculating predictions on new email.
#
# ## Files required for training
#   * Copy and paste the body of new email within the code
#
#
# ## Files saved after the compilation
#   * None
#
#
# ## Output
#   * None

# %%
# Run "newEmail_Topic_Modeling.ipynb"
# !cp "/content/drive/Shared drives/RA2 TechCareers Model Data/New_Donor_Prediction/newEmail_Topic_Modeling.ipynb" "newEmail_Topic_Modeling.ipynb"
# %run 'newEmail_Topic_Modeling.ipynb'

# %% [markdown]
# # **Prediction on new Email with DL - ANN model**
#
# This code with use the ANN model trained on data and give a histogram chart of users opening a new email.
# * 0 ---> Not opening
# * 1 ---> Opening
#
# ## Files required for training
#   * newEmail_Topic_Modeling.ipynb
#   * base_features_ANN.pkl
#   * New_Donor_ANN_Model.h5
#
#
# ## Files saved after the compilation
#   * None
#
#
# ## Output
#   * Histogram chart with predictions for all user IDs

# %%
# Run "New_Doner_ANN_Prediction.ipynb"
# !cp "/content/drive/Shared drives/RA2 TechCareers Model Data/New_Donor_Prediction/New_Doner_ANN_Prediction.ipynb" "New_Doner_ANN_Prediction.ipynb"
# %run 'New_Doner_ANN_Prediction.ipynb'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Using TensorFlow backend.
# /content/drive/Shared drives/RA2 TechCareers Model Data/New_Donor_Prediction
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      |████████████████████████████████| 317kB 4.0MB/s
#      |████████████████████████████████| 245kB 9.0MB/s
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ...
#      |████████████████████████████████| 24.2MB 1.5MB/s
# ...
#   Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# ...

# %% [markdown]
# # **Prediction on new Email with ML - Random Forest model**
#
# This code will use the RF model trained on data and give a histogram chart of users opening a new email.
# * 0 ---> Not opening
# * 1 ---> Opening
#
# ## Files required for training
#   * newEmail_Topic_Modeling.ipynb
#   * base_features_ML.pkl
#   * Random_Forest_model_KK.sav
#
#
# ## Files saved after the compilation
#   * None
#
#
# ## Output
#   * Histogram chart with predictions for all user IDs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Run "New_Doner_ML_Prediction.ipynb"
# !cp "/content/drive/Shared drives/RA2 TechCareers Model Data/New_Donor_Prediction/New_Doner_ML_Prediction.ipynb" "New_Doner_ML_Prediction.ipynb"
# %run 'New_Doner_ML_Prediction.ipynb'
# Out:
# cp: '/content/drive/Shared drives/RA2 TechCareers Model Data/New_Donor_Prediction/New_Doner_ML_Prediction.ipynb' and 'New_Doner_ML_Prediction.ipynb' are the same file
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/Shared drives/RA2 TechCareers Model Data/New_Donor_Prediction
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# Requirement already up-to-date: gensim in /usr/local/lib/python3.6/dist-packages (3.8.3)
# ...
#
# User Count: [ 66528  55152  49602  38457  52282  46474  72645  23619  34103 161138]
# Prediction: [0.05 0.13 0.22 0.3  0.39 0.47 0.55 0.64 0.72 0.8  0.89]
